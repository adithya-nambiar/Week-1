# %% [markdown]
# ## Crop and Fertilizer Reccomendation System using ML

# %%
# Importing required libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # type: ignore
import seaborn as sns

# %%
# Retriving the data-set and defining it 
crop = pd. read_csv("dataset/Crop_recommendation.csv")

# %%
# Checking if there is any Null values 
crop.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
# Checking if any Duplicate values are present 
crop.duplicated().sum()
# Out:
# 0

# %%
# Stats of the Data-Set
crop.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
crop.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
crop.tail()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee

# %%
#
try: 
    crop = pd.read_csv("dataset/Crop_recommendation.csv")
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: File not found. Please check the file path.")
    exit()
except pd.errors.EmptyDataError:
    print("Error: The file is empty.")
    exit()
except pd.errors.ParserError:
    print("Error: There was an issue parsing the file.")
    exit()
# Out:
# Dataset loaded successfully!

# %%
crop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
crop.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
# Target feature Distribution
crop['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %%
features =crop.columns.to_list()
features.remove('label')
print(features)
# Out:
# ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']

# %%
#Visualize distribution of each feature

import matplotlib.pyplot as plt
import seaborn as sns

def plot_feature_histograms(df, features, n_cols=3, figsize_base=5):
    """
    """
    # Calculate grid dimensions
    n_features = len(features)
    n_rows = (n_features + n_cols - 1) // n_cols  # Ceiling division
    
    # Create subplots with appropriate size
    fig, axs = plt.subplots(n_rows, n_cols, 
                           figsize=(figsize_base*n_cols, figsize_base*n_rows),
                           constrained_layout=True)
    
    # Flatten axes array for easy iteration
    axs = axs.flatten()
    
    sns.set_theme(style="whitegrid", palette="pastel")
    
    # Plot each feature
    for i, (feature, ax) in enumerate(zip(features, axs)):
        sns.histplot(data=df, x=feature, ax=ax, kde=True,
                    bins='auto',
                    edgecolor='w', linewidth=0.5,
                    alpha=0.8)
        
        ax.tick_params(axis='x', rotation=30)
    
    # Removing empty subplots
    for j in range(i+1, len(axs)):
        axs[j].set_visible(False)
    
    #title
    fig.suptitle('Feature Distributions', y=1.02, fontsize=16, fontweight='bold')
    
    plt.show()

# Example usage
plot_feature_histograms(crop, features)

# %%
# Scatter Plot
import seaborn as sns
import matplotlib.pyplot as plt

num_features = len(features)  

# Create subplots
fig, ax = plt.subplots(3, 3, figsize=(15, 15))


# Plot each feature
for feature, subplot in zip(features, ax.flatten()):
    sns.scatterplot(x=feature, y='label', data=crop, ax=subplot)

# Hide empty subplots
for subplot in ax.flatten()[num_features:]:
    subplot.set_visible(False) 

# Adjust layout
plt.tight_layout()
plt.show()

# %%
#Finding outliners -boxplot
import seaborn as sns

# Assuming `features` is a list of column names and `crop` is your DataFrame
num_features = len(features)  # Number of features to plot

# Create subplots
fig, ax = plt.subplots(3, 3, figsize=(12, 15))
     

# Plot boxplot for each feature
for feature, subplot in zip(features, ax.flatten()):
    sns.boxplot(x=crop[feature], ax=subplot)
     # Add a title to each subplot

# Hide empty subplots
for subplot in ax.flatten()[num_features:]:
    subplot.set_visible(False)  # Hide unused subplots


# Adjust layout
plt.tight_layout()
plt.show()

# %%
#Correlation of the deatures 
num_cols = crop.select_dtypes(include=[np.number])
num_cols
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
corr = num_cols.corr()
corr
# Out:
#                     N         P         K  temperature  humidity        ph  \
# N            1.000000 -0.231460 -0.140512     0.026504  0.190688  0.096683
# P           -0.231460  1.000000  0.736232    -0.127541 -0.118734 -0.138019
# K           -0.140512  0.736232  1.000000    -0.160387  0.190859 -0.169503
# temperature  0.026504 -0.127541 -0.160387     1.000000  0.205320 -0.017795
# humidity     0.190688 -0.118734  0.190859     0.205320  1.000000 -0.008483
# ph           0.096683 -0.138019 -0.169503    -0.017795 -0.008483  1.000000
# rainfall     0.059020 -0.063839 -0.053461    -0.030084  0.094423 -0.109069
#
#              rainfall
# N            0.059020
# P           -0.063839
# K           -0.053461
# temperature -0.030084
# humidity     0.094423
# ph          -0.109069
# rainfall     1.000000

# %%
#Visualizing with Heatmap 

sns.heatmap(corr, annot=True,linewidths=0.9, cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# ### ENCODING

# %%
crop['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
crop_dict ={'rice':0, 
            'maize':1, 
            'chickpea':2, 
            'kidneybeans':3, 
            'mungbean':6, 
            'blackgram':7, 
            'lentil':8,
            'pomegranate':9,
            'banana':10, 
            'mango':11, 
            'grapes':12, 
            'watermelon':13, 
            'muskmelon':14, 
            'apple':15,
            'orange':16, 
            'papaya':17, 
            'coconut':18, 
            'cotton':19, 
            'jute':20, 
            'coffee':21}

# %%
crop['crop_serial']= crop['label'].map(crop_dict)
crop.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label  crop_serial
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice          0.0
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice          0.0
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice          0.0
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice          0.0
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice          0.0

# %%
crop.drop('label', axis=1, inplace=True)
crop.tail()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall  crop_serial
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507         21.0
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610         21.0
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839         21.0
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293         21.0
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041         21.0
